# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
time = np.arange(0,5,0.001)

# %%
len(time)
# Out:
# 5000

# %%
omega = 50
phi0 = np.pi/2

# %%
modelC = np.sin(np.exp^(omega) * time + phi0)

# %%
plt.plot(time, modelC)
